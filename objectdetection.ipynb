# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
path = '/content/drive/My Drive/ObjectDetection_Mask'
os.listdir(path)
# Out:
# ['requirements.txt',
#  'models.py',
#  'test.py',
#  'LICENSE',
#  'makeTxt.py',
#  'voc_label.py',
#  'README.md',
#  'labelImg',
#  'weights',
#  'cfg',
#  '__pycache__',
#  'project',
#  'data',
#  'constants.py',
#  'train.py',
#  'detect.py']

# %%
# !python /content/drive/My\ Drive/ObjectDetection_Mask/train.py
# Out:
# Namespace(accumulate=4, backend='nccl', batch_size=32, cfg='/content/drive/My Drive/ObjectDetection_Mask/cfg/yolov3-tiny.cfg', data_cfg='/content/drive/My Drive/ObjectDetection_Mask/data/rbc.data', dist_url='tcp://127.0.0.1:9999', epochs=100, evolve=False, img_size=416, multi_scale=False, nosave=False, notest=False, num_workers=4, rank=0, resume=False, transfer=False, var=0, world_size=1)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %%
# !python /content/drive/My\ Drive/ObjectDetection_Mask/detect.py
# Out:
# Namespace(cfg='/content/drive/My Drive/ObjectDetection_Mask/cfg/yolov3-tiny.cfg', conf_thres=0.5, data_cfg='/content/drive/My Drive/ObjectDetection_Mask/data/rbc.data', fourcc='mp4v', images='/content/drive/My Drive/ObjectDetection_Mask/data/samples', img_size=416, nms_thres=0.5, output='/content/drive/My Drive/ObjectDetection_Mask/output', weights='/content/drive/My Drive/ObjectDetection_Mask/weights/best.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15109MB)
#
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/8 /content/drive/My Drive/ObjectDetection_Mask/data/samples/face6.jpg: 416x320 1 unmasks, Done. (0.053s)
# ...
